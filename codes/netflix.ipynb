# %%
import pandas as pd

df = pd.read_excel(r"D:\testing\BCT_3\data\netflix_series_monthly_popularity_dataset (1).xlsx")

df.head()
# Out:
#   series_id          title    genre  release_year month_trending     views  \
# 0   SER0001  Cyber Hunters  Fantasy          2025            Jun  66182867
# 1   SER0002    Shadow City    Drama          2018            Feb  36288921
# 2   SER0003   Royal Empire   Action          2020            Feb  32132483
# 3   SER0004   Golden Crown   Sci-Fi          2024            Nov  14453367
# 4   SER0005  Broken Worlds   Action          2018            Dec  77393497
#
#      likes  rating_imdb  watch_hours_million       region
# 0  7648375          8.6                 73.8      Germany
# 1  1598146          6.2                104.6           UK
# 2  1377134          8.3                 11.5  South Korea
# 3  1516444          6.7                 25.9        India
# 4  5976951          7.5                 38.5      Germany

# %%
top_series = df.sort_values("views", ascending=False).head(10)
print(top_series[["title","views","month_trending"]])
# Out:
#               title     views month_trending
# 64    Cyber Hunters  79848896            Apr
# 242      Dark Ocean  79487338            Aug
# 220   Cyber Hunters  79295078            Jul
# 365      Dark Ocean  79274891            May
# 174   Mystic Valley  79050238            Oct
# 92   Love & Destiny  79047323            Dec
# 286  Love & Destiny  78927656            Dec
# 62     Hidden Truth  78884476            May
# 392     Future Code  78808332            Mar
# 391  Street Legends  78514806            Jun

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df["views"], bins=25)
plt.title("Distribution of Netflix Series Views")
plt.show()

# %%
df["genre"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Most Popular Netflix Genres")
plt.show()

# %%
df["genre"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Most Popular Netflix Genres")
plt.show()
