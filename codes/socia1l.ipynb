# %%
import pandas as pd

df = pd.read_excel(r"D:\testing\BCT_3\data\youtube_trending_videos_dataset_2026.xlsx")

df.head()
# Out:
#   video_id             title    channel       category upload_date     views  \
# 0  VID0001  Trending Video 1   MusicHub          Music  2026-01-05  34567890
# 1  VID0002  Trending Video 2  TechWorld     Technology  2026-01-12  12567890
# 2  VID0003  Trending Video 3   GameZone         Gaming  2026-01-20  28765432
# 3  VID0004  Trending Video 4  LearnFast      Education  2026-02-02   5678900
# 4  VID0005  Trending Video 5  FunStudio  Entertainment  2026-02-10  29876543
#
#      likes  comments  watch_time_minutes  region
# 0  2100000    120000            89000000   India
# 1   890000     45000            42000000     USA
# 2  1500000     98000            75000000      UK
# 3   350000     21000            18000000   India
# 4  1700000    110000            83000000  Canada

# %%
top_videos = df.sort_values("views", ascending=False).head(10)
print(top_videos[["title","channel","views"]])
# Out:
#                 title    channel     views
# 9   Trending Video 10   MusicHub  45678901
# 8    Trending Video 9   GameZone  35678901
# 0    Trending Video 1   MusicHub  34567890
# 4    Trending Video 5  FunStudio  29876543
# 2    Trending Video 3   GameZone  28765432
# 12  Trending Video 13  FunStudio  27654321
# 10  Trending Video 11  TechWorld  22345678
# 5    Trending Video 6     SportX  19876543
# 13  Trending Video 14     SportX  18654321
# 1    Trending Video 2  TechWorld  12567890

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df["views"], bins=30)

plt.title("Distribution of YouTube Video Views")
plt.show()

# %%
df["category"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("Most Popular YouTube Categories")
plt.show()
